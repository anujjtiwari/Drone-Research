# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
# Out:
# 2024-05-03 01:27:20.837987: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 01:27:20.838168: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 01:27:20.891539: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 01:27:21.011074: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 01:27:22.776085: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load the flight logs into a DataFrame
df  = pd.read_csv('/home/anujtiwari/projects/drones/FlightLogs/FLY034.csv', low_memory=False)

# %%
# selected_features = []

# %%
# for el in df.columns:
#     if 'velE' in el:
#         selected_features.append(el)

# %%
# selected_features

# %%
# IMU_ATTI(0):accelX
# IMU_ATTI(0):accelY
# IMU_ATTI(0):accelZ
selected_features = ['IMU_ATTI(0):Longitude', 'IMU_ATTI(0):Latitude', 'IMU_ATTI(0):velN', 'IMU_ATTI(0):velE']


# add more features
selected_features += ['IMU_ATTI(0):accelX', 'IMU_ATTI(0):accelY', 'IMU_ATTI(0):accelZ']


df = df[selected_features]

# %%
# find how many duplicate values are there
df.duplicated().sum()

# remove all the duplicate values
df = df.drop_duplicates()



# remove all the missing values
df = df.dropna()

# %%
df.shape
# Out:
# (0, 7)

# %%
# find how many missing values are there
df.isnull().sum()
# Out:
# IMU_ATTI(0):Longitude    0.0
# IMU_ATTI(0):Latitude     0.0
# IMU_ATTI(0):velN         0.0
# IMU_ATTI(0):velE         0.0
# IMU_ATTI(0):accelX       0.0
# IMU_ATTI(0):accelY       0.0
# IMU_ATTI(0):accelZ       0.0
# dtype: float64

# %%
# remove alternate rows
df = df[::2]
df = df[::2]
df = df[::2]
df = df[::2]
df = df[::2]
df = df[::2]

# %%
df.shape
# Out:
# (0, 7)

# %%
real_last_100 = df.iloc[-100:]

# remove the last 1000 values
df = df.iloc[:-100]

# %%
# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Normalize the data
#       2 scaler = MinMaxScaler()
# ----> 3 scaled_data = scaler.fit_transform(df)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:915, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     911 # non-optimized default implementation; override when a better
#     912 # method is possible for a given clustering algorithm
#     913 if y is None:
#     914     # fit method of arity 1 (unsupervised transformation)
# --> 915     return self.fit(X, **fit_params).transform(X)
#     916 else:
#     917     # fit method of arity 2 (supervised transformation)
#     918     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:434, in MinMaxScaler.fit(self, X, y)
#     432 # Reset internal state before fitting
#     433 self._reset()
# --> 434 return self.partial_fit(X, y)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:472, in MinMaxScaler.partial_fit(self, X, y)
#     466     raise TypeError(
#     467         "MinMaxScaler does not support sparse input. "
#     468         "Consider using MaxAbsScaler instead."
#     469     )
#     471 first_pass = not hasattr(self, "n_samples_seen_")
# --> 472 X = self._validate_data(
#     473     X,
#     474     reset=first_pass,
#     475     dtype=FLOAT_DTYPES,
#     476     force_all_finite="allow-nan",
#     477 )
#     479 data_min = np.nanmin(X, axis=0)
#     480 data_max = np.nanmax(X, axis=0)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:969, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     967     n_samples = _num_samples(array)
#     968     if n_samples < ensure_min_samples:
# --> 969         raise ValueError(
#     970             "Found array with %d sample(s) (shape=%s) while a"
#     971             " minimum of %d is required%s."
#     972             % (n_samples, array.shape, ensure_min_samples, context)
#     973         )
#     975 if ensure_min_features > 0 and array.ndim == 2:
#     976     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 7)) while a minimum of 1 is required by MinMaxScaler.

# %%
# Function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Define sequence length
sequence_length = 10

# %%
# Create sequences
X, y = create_sequences(scaled_data, sequence_length)

# %%
# Split data into train and test sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
# Define and train LSTM model
model = Sequential()

# add more layers to the model
model.add(LSTM(units=50, activation='relu', return_sequences=True))
model.add(LSTM(units=50, activation='relu'))
model.add(Dense(units=4))

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=2)
# Out:
# Epoch 1/100
# 6/6 - 2s - 401ms/step - accuracy: 0.0298 - loss: 0.4440
# Epoch 2/100
# 6/6 - 0s - 9ms/step - accuracy: 0.5119 - loss: 0.3761
# Epoch 3/100
# 6/6 - 0s - 15ms/step - accuracy: 0.8452 - loss: 0.2877
# Epoch 4/100
# 6/6 - 0s - 7ms/step - accuracy: 0.8452 - loss: 0.1229
# Epoch 5/100
# 6/6 - 0s - 8ms/step - accuracy: 0.8452 - loss: 0.0545
# Epoch 6/100
# 6/6 - 0s - 7ms/step - accuracy: 0.6488 - loss: 0.0368
# Epoch 7/100
# 6/6 - 0s - 10ms/step - accuracy: 0.8631 - loss: 0.0348
# Epoch 8/100
# 6/6 - 0s - 11ms/step - accuracy: 0.8452 - loss: 0.0269
# Epoch 9/100
# 6/6 - 0s - 9ms/step - accuracy: 0.8452 - loss: 0.0246
# Epoch 10/100
# 6/6 - 0s - 9ms/step - accuracy: 0.8452 - loss: 0.0220
# Epoch 11/100
# 6/6 - 0s - 9ms/step - accuracy: 0.8750 - loss: 0.0190
# Epoch 12/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9583 - loss: 0.0164
# Epoch 13/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9524 - loss: 0.0152
# Epoch 14/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9524 - loss: 0.0118
# Epoch 15/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9643 - loss: 0.0108
# Epoch 16/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9643 - loss: 0.0087
# Epoch 17/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0082
# Epoch 18/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0079
# Epoch 19/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0096
# Epoch 20/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9405 - loss: 0.0091
# Epoch 21/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0087
# Epoch 22/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0075
# Epoch 23/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0082
# Epoch 24/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0076
# Epoch 25/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0071
# Epoch 26/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0078
# Epoch 27/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9702 - loss: 0.0068
# Epoch 28/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0069
# Epoch 29/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0074
# Epoch 30/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9702 - loss: 0.0073
# Epoch 31/100
# 6/6 - 0s - 11ms/step - accuracy: 0.9702 - loss: 0.0069
# Epoch 32/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9702 - loss: 0.0069
# Epoch 33/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9702 - loss: 0.0065
# Epoch 34/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0060
# Epoch 35/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0078
# Epoch 36/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0063
# Epoch 37/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9643 - loss: 0.0067
# Epoch 38/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0063
# Epoch 39/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9643 - loss: 0.0076
# Epoch 40/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9702 - loss: 0.0074
# Epoch 41/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9702 - loss: 0.0063
# Epoch 42/100
# 6/6 - 0s - 13ms/step - accuracy: 0.9643 - loss: 0.0070
# Epoch 43/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9286 - loss: 0.0068
# Epoch 44/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9702 - loss: 0.0060
# Epoch 45/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9583 - loss: 0.0059
# Epoch 46/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9702 - loss: 0.0054
# Epoch 47/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9702 - loss: 0.0051
# Epoch 48/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0057
# Epoch 49/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9643 - loss: 0.0055
# Epoch 50/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0054
# Epoch 51/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0049
# Epoch 52/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0049
# Epoch 53/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9702 - loss: 0.0047
# Epoch 54/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9643 - loss: 0.0052
# Epoch 55/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0049
# Epoch 56/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0048
# Epoch 57/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0052
# Epoch 58/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0050
# Epoch 59/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0053
# Epoch 60/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0055
# Epoch 61/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0062
# Epoch 62/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0051
# Epoch 63/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0047
# Epoch 64/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9643 - loss: 0.0047
# Epoch 65/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9643 - loss: 0.0051
# Epoch 66/100
# 6/6 - 0s - 11ms/step - accuracy: 0.9643 - loss: 0.0044
# Epoch 67/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9702 - loss: 0.0049
# Epoch 68/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9643 - loss: 0.0057
# Epoch 69/100
# 6/6 - 0s - 17ms/step - accuracy: 0.9643 - loss: 0.0046
# Epoch 70/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0052
# Epoch 71/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0045
# Epoch 72/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0044
# Epoch 73/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0047
# Epoch 74/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0041
# Epoch 75/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9702 - loss: 0.0045
# Epoch 76/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0038
# Epoch 77/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0043
# Epoch 78/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9702 - loss: 0.0043
# Epoch 79/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0042
# Epoch 80/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0043
# Epoch 81/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9643 - loss: 0.0048
# Epoch 82/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9643 - loss: 0.0044
# Epoch 83/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9702 - loss: 0.0044
# Epoch 84/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0049
# Epoch 85/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0054
# Epoch 86/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0040
# Epoch 87/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0035
# Epoch 88/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0041
# Epoch 89/100
# 6/6 - 0s - 11ms/step - accuracy: 0.9702 - loss: 0.0040
# Epoch 90/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9643 - loss: 0.0040
# Epoch 91/100
# 6/6 - 0s - 9ms/step - accuracy: 0.9702 - loss: 0.0039
# Epoch 92/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0037
# Epoch 93/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0035
# Epoch 94/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0039
# Epoch 95/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9643 - loss: 0.0036
# Epoch 96/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9702 - loss: 0.0038
# Epoch 97/100
# 6/6 - 0s - 7ms/step - accuracy: 0.9702 - loss: 0.0033
# Epoch 98/100
# 6/6 - 0s - 10ms/step - accuracy: 0.9643 - loss: 0.0034
# Epoch 99/100
# 6/6 - 0s - 8ms/step - accuracy: 0.9702 - loss: 0.0032
# Epoch 100/100
# 6/6 - 0s - 14ms/step - accuracy: 0.9643 - loss: 0.0040

# %%
# Predict next 100 coordinates
predicted_coordinates = []
current_sequence = X_test[-1]
for _ in range(100):
    prediction = model.predict(current_sequence.reshape(1, sequence_length, 4))
    predicted_coordinates.append(prediction)
    current_sequence = np.append(current_sequence[1:], prediction, axis=0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Inverse transform the predicted coordinates
predicted_coordinates = scaler.inverse_transform(np.array(predicted_coordinates).reshape(-1, 4))

# %%
# Add predicted coordinates to actual data frame
predicted_df = pd.DataFrame(predicted_coordinates, columns=selected_features)
# data = pd.concat([df, predicted_df], ignore_index=True)

# %%
df.shape
# Out:
# (220, 4)

# %%
model.summary()
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_23 (LSTM)                  │ (None, 10, 50)         │        11,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_24 (LSTM)                  │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,214 (368.03 KB)
#  Trainable params: 31,404 (122.67 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 62,810 (245.36 KB)

# %%
plt.figure(figsize=(50, 30))
plt.scatter(df['IMU_ATTI(0):Longitude'], df['IMU_ATTI(0):Latitude'], label='Actual', color='blue')
plt.scatter(real_last_100['IMU_ATTI(0):Longitude'], real_last_100['IMU_ATTI(0):Latitude'], label='Real Last 100', color='red')
plt.scatter(predicted_df['IMU_ATTI(0):Longitude'], predicted_df['IMU_ATTI(0):Latitude'], label='Predicted', color='green')

# %%
# Out:
#   Cell In[16], line 24
#     def main():
#                ^
# SyntaxError: incomplete input

# %%
import pandas as pd
import folium
from IPython.display import display

# Read the dataset and extract GPS coordinates
def read_dataset(file_path):
    # Assuming the dataset is in CSV format
    df = pd.read_csv(file_path)
    # Assuming the columns are named 'Latitude' and 'Longitude'
    gps_coordinates = df[['IMU_ATTI(0):Longitude', 'IMU_ATTI(0):Latitude']].dropna().values.tolist()
    return gps_coordinates

# Create Folium map
def create_map():
    return folium.Map(location=[0, 0], zoom_start=100)  # You can adjust the initial location and zoom level as needed

# Add markers for GPS coordinates on the Folium map
def add_markers(map_obj, gps_coordinates):
    for coord in gps_coordinates:
        lat, lon = coord
        folium.Marker(location=[float(lat), float(lon)]).add_to(map_obj)

# Main function
def main():
    dataset_file_path = 'FlightLogs/FLY006.csv'  # Update with your dataset file path
    gps_coordinates = read_dataset(dataset_file_path)
    if gps_coordinates:
        drone_map = create_map()
        add_markers(drone_map, gps_coordinates)
        display(drone_map)  # Display the map directly in Jupyter Notebook or similar environments
        print("Map generated successfully.")
    else:
        print("No GPS coordinates found in the dataset.")

if __name__ == "__main__":
    main()
# Out:
# /tmp/ipykernel_5757/3684895996.py:8: DtypeWarning: Columns (49,50,169,170,171,172,173,174,175,176,177,178,244,246,248,249,250,293) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1baac3d35474f537fc01a12ae1e11ac8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1baac3d35474f537fc01a12ae1e11ac8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1baac3d35474f537fc01a12ae1e11ac8 = L.map(
#                 &quot;map_1baac3d35474f537fc01a12ae1e11ac8&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 100,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a5d826cd072fabb79229abdb2872a21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5a5d826cd072fabb79229abdb2872a21.addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_1d22da996c840151b11f5f9782d47189 = L.marker(
#                 [-106.2163858534453, 39.961229637667294],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_c031124d22a102457823709ac9f121fa = L.marker(
#                 [-106.21638585154962, 39.96122966407761],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_4e0a3aabe622c4695afe86053407bb26 = L.marker(
#                 [-106.21638585007038, 39.96122968664815],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_7dae684cc674c2472cd24d0db8519462 = L.marker(
#                 [-106.21638585729198, 39.96122973799746],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_d1d3d4f58b252ee05885d95658b1c01f = L.marker(
#                 [-106.2163858665269, 39.961229772822094],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_0e26750166eb92d18e6a9a1c482c9245 = L.marker(
#                 [-106.2163858745436, 39.96122980261422],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_35f643b5f1c7522159ad2a81c6155490 = L.marker(
#                 [-106.21638588398842, 39.96122983734792],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_a09a7e4d31c4963c2d2686541b385aec = L.marker(
#                 [-106.21638589365313, 39.96122987205234],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_7c118989e181cf8224a45022d5970f69 = L.marker(
#                 [-106.21638590340876, 39.961229906677445],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_aeaf9d546415eb3932cdcd5215720454 = L.marker(
#                 [-106.21638591030982, 39.961229946373],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_fdac785cab3dc9c1bc2e437ee5b49d3d = L.marker(
#                 [-106.2163859162264, 39.96122997501397],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_7676e28c233210ddd47d62917c541cc3 = L.marker(
#                 [-106.21638592229728, 39.96123000351541],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_ad087de9e1dff00e6f93cd700af771c4 = L.marker(
#                 [-106.21638592755612, 39.96123002792721],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_a116c400d8cd2ad0b159e13b2d3312d9 = L.marker(
#                 [-106.21638593378832, 39.9612300564832],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_cfa563baf7afe58953ad38c8d8ec4c02 = L.marker(
#                 [-106.21638594016416, 39.96123008504488],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_f67d962904a879c42fcd571d55455ee3 = L.marker(
#                 [-106.21638594070046, 39.96123013136597],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_41e5664255b31153c7bbf170c81a43ce = L.marker(
#                 [-106.21638594349596, 39.96123016070361],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_e60bd53a2efce51733a373aabf69d1bb = L.marker(
#                 [-106.21638594694464, 39.96123019490002],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_4a381915f82a573f64b4a065e4474d3d = L.marker(
#                 [-106.21638595050771, 39.96123022905704],
#                 {}
#             ).addTo(map_1baac3d35474f537fc01a12ae1e11ac8);
#
#
#             var marker_2b
# Map generated successfully.
